# %%
import qcfractal.interface as ptl
client = ptl.FractalClient(address="localhost:7777", verify=False)

# %% [markdown]
# # 1. Create a collection (OptmizationDataset)

# %% [markdown]
# first create a collection that will contain all of your small molecules

# %%
ds_mols = ptl.collections.OptimizationDataset("project_molecules", client=client)
ds_mols.save()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 ds_mols = ptl.collections.OptimizationDataset("project_molecules", client=client)
# ----> 2 ds_mols.save()
#
# File ~/.miniforge/envs/beep/lib/python3.10/site-packages/qcfractal/interface/collections/collection.py:249, in Collection.save(self, client)
#     247     response = client.add_collection(self.data.dict(), overwrite=False, full_return=True)
#     248     if response.meta.success is False:
# --> 249         raise KeyError(f"Error adding collection: \n{response.meta.error_description}")
#     250     self.data.__dict__["id"] = response.data
#     251 else:
#
# KeyError: 'Error adding collection: \n(psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ix_collection_lname"\nDETAIL:  Key (collection, lname)=(optimizationdataset, project_molecules) already exists.\n\n[SQL: INSERT INTO collection (collection_type, collection, lname, name, tags, tagline, description, "group", visibility, view_url_hdf5, view_url_plaintext, view_metadata, view_available, provenance, extra) VALUES (%(collection_type)s, %(collection)s, %(lname)s, %(name)s, %(tags)s, %(tagline)s, %(description)s, %(group)s, %(visibility)s, %(view_url_hdf5)s, %(view_url_plaintext)s, %(view_metadata)s, %(view_available)s, %(provenance)s, %(extra)s) RETURNING collection.id]\n[parameters: {\'collection_type\': None, \'collection\': \'optimizationdataset\', \'lname\': \'project_molecules\', \'name\': \'project_molecules\', \'tags\': \'[]\', \'tagline\': None, \'description\': None, \'group\': \'default\', \'visibility\': True, \'view_url_hdf5\': None, \'view_url_plaintext\': None, \'view_metadata\': \'null\', \'view_available\': False, \'provenance\': \'{}\', \'extra\': \'{"specs": {}, "records": {}, "metadata": {}, "history": []}\'}]\n(Background on this error at: http://sqlalche.me/e/13/gkpj)'

# %% [markdown]
# # 2. load the collection beforehand

# %%
ds_mols = client.get_collection('OptimizationDataset', 'project_molecules')

# %% [markdown]
#  # 3. create a molecule xyz and an object

# %% [markdown]
# now add a small molecule eg water to the collection

# %%
h2o_xyz = '''O          0.00000        0.00000        0.11765
    H          0.00000        0.76012       -0.47058
    H          0.00000       -0.76012       -0.47058
'''

# %%
mol_h2o = ptl.Molecule.from_data(h2o_xyz)

# %% [markdown]
# visualise

# %%
mol_h2o
# Out:
# NGLWidget()

# %% [markdown]
# # 4. Add water to your project_moelecules collection:

# %%
ds_mols.add_entry("h2o", mol_h2o)
ds_mols.save()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ds_mols.add_entry("h2o", mol_h2o)
#       2 ds_mols.save()
#
# File ~/anaconda3/envs/beep/lib/python3.9/site-packages/qcfractal/interface/collections/optimization_dataset.py:144, in OptimizationDataset.add_entry(self, name, initial_molecule, additional_keywords, attributes, save)
#     139 molecule_id = self.client.add_molecules([initial_molecule])[0]
#     140 entry = OptEntry(
#     141     name=name, initial_molecule=molecule_id, additional_keywords=additional_keywords, attributes=attributes
#     142 )
# --> 144 self._add_entry(name, entry, save)
#
# File ~/anaconda3/envs/beep/lib/python3.9/site-packages/qcfractal/interface/collections/collection.py:414, in BaseProcedureDataset._add_entry(self, name, record, save)
#     412 self.data.records[name.lower()] = record
#     413 if save:
# --> 414     self.save()
#
# File ~/anaconda3/envs/beep/lib/python3.9/site-packages/qcfractal/interface/collections/collection.py:249, in Collection.save(self, client)
#     247     response = client.add_collection(self.data.dict(), overwrite=False, full_return=True)
#     248     if response.meta.success is False:
# --> 249         raise KeyError(f"Error adding collection: \n{response.meta.error_description}")
#     250     self.data.__dict__["id"] = response.data
#     251 else:
#
# KeyError: 'Error adding collection: \n(psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ix_collection_lname"\nDETAIL:  Key (collection, lname)=(optimizationdataset, project_molecules) already exists.\n\n[SQL: INSERT INTO collection (collection_type, collection, lname, name, tags, tagline, description, "group", visibility, view_url_hdf5, view_url_plaintext, view_metadata, view_available, provenance, extra) VALUES (%(collection_type)s, %(collection)s, %(lname)s, %(name)s, %(tags)s, %(tagline)s, %(description)s, %(group)s, %(visibility)s, %(view_url_hdf5)s, %(view_url_plaintext)s, %(view_metadata)s, %(view_available)s, %(provenance)s, %(extra)s) RETURNING collection.id]\n[parameters: {\'collection_type\': None, \'collection\': \'optimizationdataset\', \'lname\': \'project_molecules\', \'name\': \'project_molecules\', \'tags\': \'[]\', \'tagline\': None, \'description\': None, \'group\': \'default\', \'visibility\': True, \'view_url_hdf5\': None, \'view_url_plaintext\': None, \'view_metadata\': \'null\', \'view_available\': False, \'provenance\': \'{}\', \'extra\': \'{"specs": {}, "records": {"h2o": {"name": "h2o", "initial_molecule": "6873", "additional_keywords": {}, "attributes": {}, "object_map": {}}}, "metadata": {}, "history": []}\'}]\n(Background on this error at: http://sqlalche.me/e/13/gkpj)'

# %% [markdown]
# # 5. Send the geometry optimsation for water

# %% [markdown]
# first add the specifation

# %%
add_spec = {'name': 'blyp-d3bj_def2-svpd',
        'description': 'Geometric + Psi4/blyp-d3bj/def2-svpd.',
        'optimization_spec': {'program': 'geometric', 'keywords': None},
        'qc_spec': {'driver': 'gradient',
        'method': 'blyp-d3bj',
        'basis': 'def2-svpd',
        'keywords': None,
        'program': 'psi4'}}
ds_mols.add_specification(**add_spec,overwrite=True)
ds_mols.save()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 9
#       1 add_spec = {'name': 'blyp-d3bj_def2-svpd',
#       2         'description': 'Geometric + Psi4/blyp-d3bj/def2-svpd.',
#       3         'optimization_spec': {'program': 'geometric', 'keywords': None},
#    (...)
#       7         'keywords': None,
#       8         'program': 'psi4'}}
# ----> 9 ds_mols.add_specification(**add_spec,overwrite=True)
#      10 ds_mols.save()
#
# File ~/anaconda3/envs/beep/lib/python3.9/site-packages/qcfractal/interface/collections/optimization_dataset.py:104, in OptimizationDataset.add_specification(self, name, optimization_spec, qc_spec, description, protocols, overwrite)
#      94     protocols = {}
#      96 spec = OptEntrySpecification(
#      97     name=name,
#      98     optimization_spec=optimization_spec,
#    (...)
#     101     protocols=protocols,
#     102 )
# --> 104 return self._add_specification(name, spec, overwrite=overwrite)
#
# File ~/anaconda3/envs/beep/lib/python3.9/site-packages/qcfractal/interface/collections/collection.py:324, in BaseProcedureDataset._add_specification(self, name, spec, overwrite)
#     321     raise KeyError(f"{self.__class__.__name__} '{name}' already present, use `overwrite=True` to replace.")
#     323 self.data.specs[lname] = spec
# --> 324 self.save()
#
# File ~/anaconda3/envs/beep/lib/python3.9/site-packages/qcfractal/interface/collections/collection.py:249, in Collection.save(self, client)
#     247     response = client.add_collection(self.data.dict(), overwrite=False, full_return=True)
#     248     if response.meta.success is False:
# --> 249         raise KeyError(f"Error adding collection: \n{response.meta.error_description}")
#     250     self.data.__dict__["id"] = response.data
#     251 else:
#
# KeyError: 'Error adding collection: \n(psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ix_collection_lname"\nDETAIL:  Key (collection, lname)=(optimizationdataset, project_molecules) already exists.\n\n[SQL: INSERT INTO collection (collection_type, collection, lname, name, tags, tagline, description, "group", visibility, view_url_hdf5, view_url_plaintext, view_metadata, view_available, provenance, extra) VALUES (%(collection_type)s, %(collection)s, %(lname)s, %(name)s, %(tags)s, %(tagline)s, %(description)s, %(group)s, %(visibility)s, %(view_url_hdf5)s, %(view_url_plaintext)s, %(view_metadata)s, %(view_available)s, %(provenance)s, %(extra)s) RETURNING collection.id]\n[parameters: {\'collection_type\': None, \'collection\': \'optimizationdataset\', \'lname\': \'project_molecules\', \'name\': \'project_molecules\', \'tags\': \'[]\', \'tagline\': None, \'description\': None, \'group\': \'default\', \'visibility\': True, \'view_url_hdf5\': None, \'view_url_plaintext\': None, \'view_metadata\': \'null\', \'view_available\': False, \'provenance\': \'{}\', \'extra\': \'{"specs": {"blyp-d3bj_def2-svpd": {"name": "blyp-d3bj_def2-svpd", "description": "Geometric + Psi4/blyp-d3bj/def2-svpd.", "optimization_spec": {"prog ... (183 characters truncated) ... : {"h2o": {"name": "h2o", "initial_molecule": "6873", "additional_keywords": {}, "attributes": {}, "object_map": {}}}, "metadata": {}, "history": []}\'}]\n(Background on this error at: http://sqlalche.me/e/13/gkpj)'

# %% [markdown]
# here you specify the level of theory and basis set, play around and save a few specifications

# %%
ds_mols.compute('mpwb1k-d3bj_def2-svpd', tag='basic_small',subset={'NH2'})
# Out:
# 0

# %% [markdown]
# run the following to see if the the water molecules has computed

# %%
ds_mols  = client.get_collection("OptimizationDataset", "project_molecules")
ds_mols.status(collapse = False)
# Out:
#         blyp-d3bj_def2-svpd b3lyp-d3bj_def2-svpd hf-3c-d3bj_MINIX  \
# CH4                    None                 None             None
# C2H2                   None                 None             None
# CO2_CO                 None                 None             None
# H2O_H2O                None                 None             None
# H2O                    None                 None             None
# CO2_CO2                None                 None             None
# CO                     None                 None             None
# CH3OH                  None                 None             None
# CO2                    None                 None             None
# H2CO                   None                 None             None
# CH2OH                  None                 None             None
# CH3O                   None                 None             None
# CH3                    None                 None             None
# H2S                    None                 None             None
# H2                     None                 None             None
# HCl                    None                 None             None
# HCN                    None                 None             None
# HCOOH                  None                 None             None
# HCO                    None                 None             None
# HF                     None                 None             None
# HNC                    None                 None             None
# N2                     None                 None             None
# NH2                    None                 None             None
# NH3                    None                 None             None
# NHCH2                  None                 None             None
# OH                     None                 None             None
#
#         b3lyp_def2-svpd hf-3c_MINIX hf-d3bj_sto-3g hf_sto-3g hf_MINIX  \
# CH4                None        None           None      None     None
# C2H2               None        None           None      None     None
# CO2_CO             None        None           None      None     None
# H2O_H2O            None        None           None      None     None
# H2O                None        None           None      None     None
# CO2_CO2            None        None           None      None     None
# CO                 None        None           None      None     None
# CH3OH              None        None           None      None     None
# CO2                None        None           None      None     None
# H2CO               None        None           None      None     None
# CH2OH              None        None           None      None     None
# CH3O               None        None           None      None     None
# CH3                None        None           None      None     None
# H2S                None        None           None      None     None
# H2                 None        None           None      None     None
# HCl                None        None           None      None     None
# HCN                None        None           None      None     None
# HCOOH              None        None           None      None     None
# HCO                None        None           None      None     None
# HF                 None        None           None      None     None
# HNC                None        None           None      None     None
# N2                 None        None           None      None     None
# NH2                None        None           None      None     None
# NH3                None        None           None      None     None
# NHCH2              None        None           None      None     None
# OH                 None        None           None      None     None
#
#         mpwb1k-d3bj_def2-tzvp mpwb1k-d3bj_def2-svpd
# CH4                  COMPLETE              COMPLETE
# C2H2                 COMPLETE              COMPLETE
# CO2_CO               COMPLETE              COMPLETE
# H2O_H2O              COMPLETE              COMPLETE
# H2O                  COMPLETE              COMPLETE
# CO2_CO2              COMPLETE              COMPLETE
# CO                   COMPLETE              COMPLETE
# CH3OH                COMPLETE              COMPLETE
# CO2                  COMPLETE              COMPLETE
# H2CO                 COMPLETE              COMPLETE
# CH2OH                COMPLETE              COMPLETE
# CH3O                 COMPLETE              COMPLETE
# CH3                  COMPLETE              COMPLETE
# H2S                  COMPLETE              COMPLETE
# H2                   COMPLETE              COMPLETE
# HCl                  COMPLETE              COMPLETE
# HCN                  COMPLETE              COMPLETE
# HCOOH                COMPLETE              COMPLETE
# HCO                  COMPLETE              COMPLETE
# HF                   COMPLETE              COMPLETE
# HNC                  COMPLETE              COMPLETE
# N2                   COMPLETE              COMPLETE
# NH2                  COMPLETE                 ERROR
# NH3                  COMPLETE              COMPLETE
# NHCH2                COMPLETE              COMPLETE
# OH                   COMPLETE              COMPLETE

# %% [markdown]
# # 6. Now follow this workflow for your additonal molecules

# %% [markdown]
# CH3OH, CO2, CO, H2CO

# %% [markdown]
# make the xyz files on avogadro and put those into the workbook and follow the wokrflow

# %% [markdown]
# Bonus points if you make a loop for this workflow #nopressure

# %% [markdown]
# ## Creating a class of the workflow

# %%
class workflow():
    
    def __init__(self,dataset,molecule,name):
        self.dataset = client.get_collection('OptimizationDataset','project_molecules')
        self.molecule=molecule
        self.xyz_file = f'/home/fastdata/Shared/Molecules/{molecule}.xyz' # as in the command line
        self.name = name
        
    def create_molecule(self):
        with open(self.xyz_file,'r') as file:
            lines=file.readlines()[2:]
            lines=[' '.join(line.split()) for line in lines] # clean each line by stripping extra speaces and newlines and join them with a single space   
            lines = ''+ '\n'.join(lines)+''
            lines=str(lines)
        mol = ptl.Molecule.from_data(lines)
        return mol
        
    def add_specification(self):
        self.specification={'name':self.name, 
        'description':f'Geometric +Psi4/{self.name.split("_")[0]}/{self.name.split("_")[1]}.',
        'optimization_spec':{'program':'geometric','keywords':None},
        'qc_spec':{'driver':'gradient',
        'method':self.name.split('_')[0],
        'basis':self.name.split('_')[1],
        'keywords':None,
        'program': 'psi4'}}
            
        return self.specification
        
        
    def compute_molecule(self):
        #deleting the molecule if it exists
        if self.molecule.lower() in self.dataset.data.records:
            del self.dataset.data.records[f"{self.molecule.lower()}"]
            self.dataset.save()
            
        self.dataset.add_entry(f"{self.molecule}",
                                workflow(self.dataset,self.molecule,self.name).create_molecule())
            
        self.dataset.save()
        #adding the specification if not exists
        if workflow(self.dataset,self.molecule,self.name).add_specification()['name'].lower() not in self.dataset.data.specs:
            self.dataset.add_specification(**workflow(self.dataset,self.molecule,self.name).add_specification(),overwrite=True)
            self.dataset.save()
        
        self.dataset.compute(workflow(self.dataset,self.molecule,self.name).add_specification()['name'],tag='basic_small',
                            subset={f"{self.molecule}"})
        self.dataset=client.get_collection('OptimizationDataset','project_molecules')
        status=self.dataset.status(collapse=False)
            
        return status
        
    def check_status_only(self):
        return self.dataset.status(collapse=False)
            
    def get_results(self):
        mol_results= self.dataset.get_record(f'{self.molecule}',workflow(self.dataset,self.molecule,self.name).add_specification()['name'])
        mol_results_dict = mol_results.dict()
        return mol_results_dict,mol_results
            
            
            
CO=workflow(ds_mols,'CO','blyp-d3bj_def2-svpd')

# %%
molecules=['CO','CH3OH','CO2','H2CO','CH2OH','CH3O','CH3','H2S','H2',
           'HCl','HCN','HCOOH','HCO','HF','HNC','N2','NH2','NH3','NHCH2','OH']
list_of_mol_objects=[]

for molecule in molecules:
    optimisation=workflow(ds_mols,molecule,'mpwb1k-d3bj_def2-svpd')
    mol=optimisation.create_molecule()
    list_of_mol_objects.append(mol)
    optimisation.add_specification()
    optimisation.compute_molecule()
   
    #optimisation.get_results()[1].show_history()
    #print(optimisation.get_results()[1].energies)
    
    
    

mol_visualisation_dict={mol:object for mol,object in zip(molecules,list_of_mol_objects)}
    
mol_visualisation_dict['H2']
workflow(ds_mols,molecule,'mpwb1k-d3bj_def2-tzvp').check_status_only()
# Out:
#         blyp-d3bj_def2-svpd b3lyp-d3bj_def2-svpd hf-3c-d3bj_MINIX  \
# CH4                    None                 None             None
# C2H2                   None                 None             None
# CO2_CO                 None                 None             None
# H2O_H2O                None                 None             None
# H2O                    None                 None             None
# CO2_CO2                None                 None             None
# CO                     None                 None             None
# CH3OH                  None                 None             None
# CO2                    None                 None             None
# H2CO                   None                 None             None
# CH2OH                  None                 None             None
# CH3O                   None                 None             None
# CH3                    None                 None             None
# H2S                    None                 None             None
# H2                     None                 None             None
# HCl                    None                 None             None
# HCN                    None                 None             None
# HCOOH                  None                 None             None
# HCO                    None                 None             None
# HF                     None                 None             None
# HNC                    None                 None             None
# N2                     None                 None             None
# NH2                    None                 None             None
# NH3                    None                 None             None
# NHCH2                  None                 None             None
# OH                     None                 None             None
#
#         b3lyp_def2-svpd hf-3c_MINIX hf-d3bj_sto-3g hf_sto-3g hf_MINIX  \
# CH4                None        None           None      None     None
# C2H2               None        None           None      None     None
# CO2_CO             None        None           None      None     None
# H2O_H2O            None        None           None      None     None
# H2O                None        None           None      None     None
# CO2_CO2            None        None           None      None     None
# CO                 None        None           None      None     None
# CH3OH              None        None           None      None     None
# CO2                None        None           None      None     None
# H2CO               None        None           None      None     None
# CH2OH              None        None           None      None     None
# CH3O               None        None           None      None     None
# CH3                None        None           None      None     None
# H2S                None        None           None      None     None
# H2                 None        None           None      None     None
# HCl                None        None           None      None     None
# HCN                None        None           None      None     None
# HCOOH              None        None           None      None     None
# HCO                None        None           None      None     None
# HF                 None        None           None      None     None
# HNC                None        None           None      None     None
# N2                 None        None           None      None     None
# NH2                None        None           None      None     None
# NH3                None        None           None      None     None
# NHCH2              None        None           None      None     None
# OH                 None        None           None      None     None
#
#         mpwb1k-d3bj_def2-tzvp mpwb1k-d3bj_def2-svpd
# CH4                  COMPLETE              COMPLETE
# C2H2                 COMPLETE              COMPLETE
# CO2_CO               COMPLETE              COMPLETE
# H2O_H2O              COMPLETE              COMPLETE
# H2O                  COMPLETE              COMPLETE
# CO2_CO2              COMPLETE              COMPLETE
# CO                       None              COMPLETE
# CH3OH                    None              COMPLETE
# CO2                      None              COMPLETE
# H2CO                     None              COMPLETE
# CH2OH                    None              COMPLETE
# CH3O                     None              COMPLETE
# CH3                      None              COMPLETE
# H2S                      None              COMPLETE
# H2                       None              COMPLETE
# HCl                      None              COMPLETE
# HCN                      None              COMPLETE
# HCOOH                    None              COMPLETE
# HCO                      None              COMPLETE
# HF                       None              COMPLETE
# HNC                      None              COMPLETE
# N2                       None              COMPLETE
# NH2                      None                 ERROR
# NH3                      None              COMPLETE
# NHCH2                    None              COMPLETE
# OH                       None              COMPLETE
